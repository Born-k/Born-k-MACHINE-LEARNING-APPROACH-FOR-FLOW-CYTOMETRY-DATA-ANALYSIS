# %%
# !pip install fcsy
# Out:
# Collecting fcsy
#   Downloading fcsy-0.10.0-py2.py3-none-any.whl (11 kB)
# Requirement already satisfied: numpy>=1.10.0 in /usr/local/lib/python3.7/dist-packages (from fcsy) (1.21.6)
# Requirement already satisfied: pandas>=0.24.0 in /usr/local/lib/python3.7/dist-packages (from fcsy) (1.3.5)
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/lib/python3.7/dist-packages (from pandas>=0.24.0->fcsy) (2.8.2)
# Requirement already satisfied: pytz>=2017.3 in /usr/local/lib/python3.7/dist-packages (from pandas>=0.24.0->fcsy) (2022.1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.7/dist-packages (from python-dateutil>=2.7.3->pandas>=0.24.0->fcsy) (1.15.0)
# Installing collected packages: fcsy
# Successfully installed fcsy-0.10.0

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
from fcsy import DataFrame
import pandas as pd

# %%
data = DataFrame.from_fcs('/content/drive/MyDrive/temp/AA1168_Mix1_C1.32035.fcs',channel_type = 'multi')

# %%
df = pd.DataFrame(data)
df
# Out:
# short          FSC-A          SSC-A ALEXA 488-A   ALEXA 350-A  ALEXA 750-A  \
# long
# 0       21471.119141    4921.560059   12.960001    212.400009     0.000000
# 1       43539.757812   73998.359375   41.040001   4717.440430   178.480011
# 2       20720.480469   28576.800781   16.200001     83.520004   496.640015
# 3       82162.960938   64777.324219   73.440002    211.680008   221.160004
# 4      143799.046875   81612.359375   35.640003    556.559998  6798.729980
# ...              ...            ...         ...           ...          ...
# 51807  115353.039062  255606.843750   78.840004   1157.760010   210.490005
# 51808  131538.000000  133968.609375   59.400002    185.760010   180.419998
# 51809  255808.078125  158615.281250   87.480003  31741.921875   214.370010
# 51810  108570.882812  128925.007812   75.600006     77.040001   566.480042
# 51811  171327.203125  107584.203125   52.920002     81.360001  2204.810059
#
# short        PE-A ALEXA 647-A         Time
# long
# 0      -18.799999   -1.940000     0.000000
# 1       77.080002   62.080002     0.100000
# 2       25.379999   36.860001     0.100000
# 3      212.440002  103.790001     0.100000
# 4      106.220001  454.930023     0.100000
# ...           ...         ...          ...
# 51807  428.639984  282.270020  2457.000000
# 51808  295.160004  265.779999  2457.000000
# 51809  320.540009  242.500000  2457.100098
# 51810  313.959991  257.050018  2457.300049
# 51811  421.119995  400.610016  2457.399902
#
# [51812 rows x 8 columns]

# %%
df.columns = ['FSC-A',	'SSC-A',	'ALEXA 488-A',	'ALEXA 350-A',	'ALEXA 750-A',	'PE-A',	'ALEXA 647-A', 'Time']

# %%
df.columns
# Out:
# Index(['FSC-A', 'SSC-A', 'ALEXA 488-A', 'ALEXA 350-A', 'ALEXA 750-A', 'PE-A',
#        'ALEXA 647-A', 'Time'],
#       dtype='object')

# %%
df
# Out:
#                FSC-A          SSC-A  ALEXA 488-A   ALEXA 350-A  ALEXA 750-A  \
# 0       21471.119141    4921.560059    12.960001    212.400009     0.000000
# 1       43539.757812   73998.359375    41.040001   4717.440430   178.480011
# 2       20720.480469   28576.800781    16.200001     83.520004   496.640015
# 3       82162.960938   64777.324219    73.440002    211.680008   221.160004
# 4      143799.046875   81612.359375    35.640003    556.559998  6798.729980
# ...              ...            ...          ...           ...          ...
# 51807  115353.039062  255606.843750    78.840004   1157.760010   210.490005
# 51808  131538.000000  133968.609375    59.400002    185.760010   180.419998
# 51809  255808.078125  158615.281250    87.480003  31741.921875   214.370010
# 51810  108570.882812  128925.007812    75.600006     77.040001   566.480042
# 51811  171327.203125  107584.203125    52.920002     81.360001  2204.810059
#
#              PE-A  ALEXA 647-A         Time
# 0      -18.799999    -1.940000     0.000000
# 1       77.080002    62.080002     0.100000
# 2       25.379999    36.860001     0.100000
# 3      212.440002   103.790001     0.100000
# 4      106.220001   454.930023     0.100000
# ...           ...          ...          ...
# 51807  428.639984   282.270020  2457.000000
# 51808  295.160004   265.779999  2457.000000
# 51809  320.540009   242.500000  2457.100098
# 51810  313.959991   257.050018  2457.300049
# 51811  421.119995   400.610016  2457.399902
#
# [51812 rows x 8 columns]

# %%
l = []
all = []

for i in df.columns:
    # print(i[0][-1])
  if(i[-1] != 'H' and i[-1] != 'W' and i != 'Time'):
    l.append(i)
  # df.rename(columns = {i:i[0]}, inplace = True)  
#   all.append(i)
# print(all)
l
# Out:
# ['FSC-A',
#  'SSC-A',
#  'ALEXA 488-A',
#  'ALEXA 350-A',
#  'ALEXA 750-A',
#  'PE-A',
#  'ALEXA 647-A']

# %%
df1 = df[l]
df1
# Out:
#                FSC-A          SSC-A  ALEXA 488-A   ALEXA 350-A  ALEXA 750-A  \
# 0       21471.119141    4921.560059    12.960001    212.400009     0.000000
# 1       43539.757812   73998.359375    41.040001   4717.440430   178.480011
# 2       20720.480469   28576.800781    16.200001     83.520004   496.640015
# 3       82162.960938   64777.324219    73.440002    211.680008   221.160004
# 4      143799.046875   81612.359375    35.640003    556.559998  6798.729980
# ...              ...            ...          ...           ...          ...
# 51807  115353.039062  255606.843750    78.840004   1157.760010   210.490005
# 51808  131538.000000  133968.609375    59.400002    185.760010   180.419998
# 51809  255808.078125  158615.281250    87.480003  31741.921875   214.370010
# 51810  108570.882812  128925.007812    75.600006     77.040001   566.480042
# 51811  171327.203125  107584.203125    52.920002     81.360001  2204.810059
#
#              PE-A  ALEXA 647-A
# 0      -18.799999    -1.940000
# 1       77.080002    62.080002
# 2       25.379999    36.860001
# 3      212.440002   103.790001
# 4      106.220001   454.930023
# ...           ...          ...
# 51807  428.639984   282.270020
# 51808  295.160004   265.779999
# 51809  320.540009   242.500000
# 51810  313.959991   257.050018
# 51811  421.119995   400.610016
#
# [51812 rows x 7 columns]

# %%
df = df1
df
# Out:
#                FSC-A          SSC-A  ALEXA 488-A   ALEXA 350-A  ALEXA 750-A  \
# 0       21471.119141    4921.560059    12.960001    212.400009     0.000000
# 1       43539.757812   73998.359375    41.040001   4717.440430   178.480011
# 2       20720.480469   28576.800781    16.200001     83.520004   496.640015
# 3       82162.960938   64777.324219    73.440002    211.680008   221.160004
# 4      143799.046875   81612.359375    35.640003    556.559998  6798.729980
# ...              ...            ...          ...           ...          ...
# 51807  115353.039062  255606.843750    78.840004   1157.760010   210.490005
# 51808  131538.000000  133968.609375    59.400002    185.760010   180.419998
# 51809  255808.078125  158615.281250    87.480003  31741.921875   214.370010
# 51810  108570.882812  128925.007812    75.600006     77.040001   566.480042
# 51811  171327.203125  107584.203125    52.920002     81.360001  2204.810059
#
#              PE-A  ALEXA 647-A
# 0      -18.799999    -1.940000
# 1       77.080002    62.080002
# 2       25.379999    36.860001
# 3      212.440002   103.790001
# 4      106.220001   454.930023
# ...           ...          ...
# 51807  428.639984   282.270020
# 51808  295.160004   265.779999
# 51809  320.540009   242.500000
# 51810  313.959991   257.050018
# 51811  421.119995   400.610016
#
# [51812 rows x 7 columns]

# %%
import numpy as np
import matplotlib.pyplot as plt 
from sklearn.cluster import KMeans
from sklearn.decomposition import PCA
import seaborn as sns

# %%
df.describe()
# Out:
#                FSC-A          SSC-A   ALEXA 488-A    ALEXA 350-A  \
# count   51812.000000   51812.000000  51812.000000   51812.000000
# mean   130521.281250  105958.257812     68.533997    3414.482910
# std     72601.132812   59094.562500     83.709328    8931.823242
# min      3394.159912    -187.920013   -110.160004    -104.400002
# 25%     84000.841797   78333.751953     32.400002      91.440002
# 50%    130088.199219  106955.640625     62.640003     294.480011
# 75%    179592.375000  135941.765625     92.880005    2087.460022
# max    262143.000000  262143.000000   5732.640137  262143.000000
#
#          ALEXA 750-A          PE-A   ALEXA 647-A
# count   51812.000000  51812.000000  51812.000000
# mean     3107.937256    264.576508    364.220337
# std      8335.399414    328.621368    478.638489
# min      -111.550003    -75.199997    -65.959999
# 25%       172.660004    120.320000    130.949997
# 50%       355.020020    200.220001    291.000000
# 75%      2100.050049    311.139984    483.060028
# max    262143.000000  15963.080078  20971.400391

# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
from sklearn.cluster import AgglomerativeClustering
import scipy.cluster.hierarchy as sch

# %%
X = df.iloc[:20000,[0,1]].values

# %%
# dendrogram = sch.dendrogram(sch.linkage(X, method='ward'))

# %%
from sklearn.decomposition import PCA
from sklearn.manifold import TSNE

import matplotlib.patheffects as PathEffects

# %%
def plot_TSNE(x, colors):
    num_classes = len(np.unique(colors))
    new_ndArr = np.array(sns.color_palette("hls", num_classes))
    f = plt.figure(figsize=(8, 8))
    ax = plt.subplot(aspect='equal')
    plt.title("TNSE PLOT")
    sc = ax.scatter(x[:,0], x[:,1],  c=new_ndArr[colors.astype(np.int)], cmap=plt.cm.get_cmap('Paired'))
    txts = []
    for i in range(num_classes):
        txt_x, txt_y = np.median(x[colors == i, :], axis=0)
        txt = ax.text(txt_x, txt_y, str(i), fontsize=24)
        txt.set_path_effects([
            PathEffects.Stroke(linewidth=5, foreground="w"),
            PathEffects.Normal()])
        txts.append(txt)
    return f, ax, sc, txts

# %%
model = AgglomerativeClustering(n_clusters = 7, affinity='euclidean')
model.fit(X)
labels = model.labels_

# %%
labels
# Out:
# array([3, 4, 3, ..., 2, 3, 3])

# %%
plt.figure(figsize = (6,6))
plt.scatter(X[:,0],
            X[:,1],
            c = labels,
            cmap = "winter",
            marker = "*",
            s = 75)
plt.show()

# %%
plot_TSNE(X, labels)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:7: DeprecationWarning: `np.int` is a deprecated alias for the builtin `int`. To silence this warning, use `int` by itself. Doing this will not modify any behavior and is safe. When replacing `np.int`, you may wish to use e.g. `np.int64` or `np.int32` to specify the precision. If you wish to review your current use, check the release note link for additional information.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   import sys
# (<Figure size 576x576 with 1 Axes>,
#  <matplotlib.axes._subplots.AxesSubplot at 0x7f55a7aaaa10>,
#  <matplotlib.collections.PathCollection at 0x7f55a75ea490>,
#  [Text(149920.31, 98756.28, '0'),
#   Text(262143.0, 229376.89, '1'),
#   Text(205733.0, 145489.5, '2'),
#   Text(11775.72, 8238.24, '3'),
#   Text(88689.92, 80830.445, '4'),
#   Text(149845.1, 132275.7, '5'),
#   Text(98926.08, 112534.39, '6')])

# %%
pca = PCA(n_components=2)
pca.fit(df.to_numpy())
X_pca = pca.transform(df)

kmeans_pca = KMeans(n_clusters=7, random_state=0).fit(X_pca)
labels_pca = kmeans_pca.labels_
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/base.py:444: UserWarning: X has feature names, but PCA was fitted without feature names
#   f"X has feature names, but {self.__class__.__name__} was fitted without"

# %%
pca.explained_variance_ratio_
# Out:
# array([0.8997799 , 0.08521776], dtype=float32)

# %%
plot_TSNE(X_pca, labels_pca)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:7: DeprecationWarning: `np.int` is a deprecated alias for the builtin `int`. To silence this warning, use `int` by itself. Doing this will not modify any behavior and is safe. When replacing `np.int`, you may wish to use e.g. `np.int64` or `np.int32` to specify the precision. If you wish to review your current use, check the release note link for additional information.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   import sys
# (<Figure size 576x576 with 1 Axes>,
#  <matplotlib.axes._subplots.AxesSubplot at 0x7f55a0c70290>,
#  <matplotlib.collections.PathCollection at 0x7f55a0cf7910>,
#  [Text(-43103.727, 16236.202, '0'),
#   Text(108668.57, -22562.172, '1'),
#   Text(-153397.64, -5082.5977, '2'),
#   Text(49939.137, -20248.082, '3'),
#   Text(198297.39, 41633.457, '4'),
#   Text(19024.889, 27342.025, '5'),
#   Text(-4032.1353, -11059.353, '6')])

# %%
pca = PCA(n_components=7)
principalComponents = pca.fit_transform(df.to_numpy())
features = range(pca.n_components_)
PCA_components = pd.DataFrame(principalComponents)
ratios = pca.explained_variance_ratio_*100
PCA_components
plt.xlabel('PCA features')
plt.ylabel('variance Percentage')
plt.xticks(features, rotation=70)
name = 'PCA features vs Variance Percentage'
plt.title(name)
plt.bar(features, ratios, color=sns.color_palette("flare"))
plt.show()
